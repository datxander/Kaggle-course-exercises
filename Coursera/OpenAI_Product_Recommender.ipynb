# %% [markdown]
# <a href="https://colab.research.google.com/github/datxander/Kaggle-course-exercises/blob/main/Coursera/OpenAI_Product_Recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Welcome to the notebook**

# %% [markdown]
# ### Task 1 - Set up project environment

# %% [markdown]
# Installing the needed modules

# %%
# !pip install openai==1.16.2 python-dotenv
# Out:
# Collecting openai==1.16.2
#   Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 5.9 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai==1.16.2) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai==1.16.2)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (2.7.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai==1.16.2) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.16.2) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.16.2) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.16.2) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==1.16.2)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.2 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.16.2)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (2.18.4)
# Installing collected packages: python-dotenv, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.16.2 python-dotenv-1.0.1

# %% [markdown]
# Importing the needed modules and setup the OpenAI API

# %%
import pandas as pd
import numpy as np
import os
from openai import OpenAI
from dotenv import load_dotenv
from matplotlib import pyplot as plt
import plotly.express as px

from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# Loading API key and organization ID from a dotenv file
load_dotenv(dotenv_path='apikey.env.txt')

# Retrieving API key and organization ID from environment variables
APIKEY = os.getenv("APIKEY")
# ORGID = os.getenv("ORGID")

# Creating an instance of the OpenAI client with the provided API key and organization ID
client = OpenAI(
  # organization= ORGID,
  api_key=APIKEY
)

client

# %% [markdown]
# Import our dataset

# %%
data = pd.read_csv("products_dataset.csv")
data
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description
# 0     This heavyweight, water-repellent hooded sweat...
# 1     If you need more length between your existing ...
# 2     Polyester cover resembling rich Italian tapest...
# 3     It features a rectangle shape. This vessel set...
# 4     This 9 in. black full grain leather logger boo...
# ...                                                 ...
# 1995  With a stylish monochrome look, this dotty wal...
# 1996  The Abrielle collection features a stunning as...
# 1997  With Fypon balustrade systems, you can transfo...
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...
# 1999  A refreshing take on innovative designs, Safav...
#
# [2000 rows x 3 columns]

# %% [markdown]
# List of last 8 products recently viewed by the user.

# %%
searched_products_id = [
    'P1938',
    'P1970',
    'P1044',
    'P1838',
    'P1048',
    'P1017',
    'P1310',
    'P1444',
]

# %% [markdown]
# ### Task 2 - Prepare the dataset

# %% [markdown]
# Let's label the data points that are recently veiwed.

# %%
data['product_status'] = "not_viewed"
data.loc[data.product_id.isin(searched_products_id), "product_status"] = "recently_viewed"
data[data.product_status == "recently_viewed"]
# Out:
#      product_id                                              title  \
# 1017      P1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044      P1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048      P1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310      P1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444      P1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838      P1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938      P1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970      P1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                             description   product_status
# 1017  Love your space like never before with the hig...  recently_viewed
# 1044  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1048  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1310  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1444  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1838  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1938  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1970  Introducing the best of BEHR Paint. Featuring ...  recently_viewed

# %% [markdown]
# Now let's combine the product `title` and `description` and store it into a column called `combined`.

# %%
data['combined'] = data.title + data.description
data
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster BedPolyester cover rese...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
# [2000 rows x 5 columns]

# %% [markdown]
# ### Task 3 - Text embedding and visualization

# %% [markdown]
# Creating the text embedding vectors

# %%
response = client.embeddings.create(
    input = data.combined.to_list(),
    model = "text-embedding-3-small",
    dimensions = 512
)

vectors = [d.embedding for d in response.data]
data['text_embeddings'] = vectors

data
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined  \
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster BedPolyester cover rese...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                         text_embeddings
# 0     [0.03711149841547012, 0.030765360221266747, -0...
# 1     [0.03523961082100868, 0.013278326019644737, 0....
# 2     [0.035860564559698105, -0.05905349925160408, 0...
# 3     [-0.05834035575389862, -0.007969953119754791, ...
# 4     [0.01998496614396572, 0.05075598508119583, -0....
# ...                                                 ...
# 1995  [0.0884106308221817, -0.05281016603112221, -0....
# 1996  [0.010978340171277523, -0.04043574631214142, 0...
# 1997  [-0.034120045602321625, -0.009548034518957138,...
# 1998  [-0.010843890719115734, -0.01424992736428976, ...
# 1999  [-0.013604273088276386, -0.012766680680215359,...
#
# [2000 rows x 6 columns]

# %% [markdown]
# > We know that each vector has 512 dimensions. In order to be able to visualize the vectors in a scatter plot, we need to use Principal Component Analysis (PCA) to reduce the dimension from 512 to 2.

# %%
pca = PCA(2)
vector_2d = pca.fit_transform(data.text_embeddings.to_list())

data['pc1'] = vector_2d[:,0]
data['pc2'] = vector_2d[:,1]

data
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined  \
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster BedPolyester cover rese...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                         text_embeddings       pc1       pc2
# 0     [0.03711149841547012, 0.030765360221266747, -0... -0.012653 -0.072015
# 1     [0.03523961082100868, 0.013278326019644737, 0.... -0.357218 -0.236114
# 2     [0.035860564559698105, -0.05905349925160408, 0... -0.201098  0.206638
# 3     [-0.05834035575389862, -0.007969953119754791, ... -0.181800 -0.043369
# 4     [0.01998496614396572, 0.05075598508119583, -0.... -0.214504 -0.141169
# ...                                                 ...       ...       ...
# 1995  [0.0884106308221817, -0.05281016603112221, -0.... -0.042146  0.196837
# 1996  [0.010978340171277523, -0.04043574631214142, 0... -0.246728  0.481593
# 1997  [-0.034120045602321625, -0.009548034518957138,... -0.082867 -0.103881
# 1998  [-0.010843890719115734, -0.01424992736428976, ...  0.506971 -0.005701
# 1999  [-0.013604273088276386, -0.012766680680215359,... -0.280840  0.430882
#
# [2000 rows x 8 columns]

# %% [markdown]
# Now that we have the text embedding vectors in two dimensions, we can use them to create a 2D plot.

# %%
px.scatter(data, x = 'pc1', y = 'pc2', color = 'product_status')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3c1d5cf4-2d70-4841-bd09-9c3161e7e383" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c1d5cf4-2d70-4841-bd09-9c3161e7e383")) {                    Plotly.newPlot(                        "3c1d5cf4-2d70-4841-bd09-9c3161e7e383",                        [{"hovertemplate":"product_status=not_viewed\u003cbr\u003epc1=%{x}\u003cbr\u003epc2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"not_viewed","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"not_viewed","showlegend":true,"x":[-0.012653163472377485,-0.3572180062101936,-0.2010977429202079,-0.18179969770544616,-0.21450385264922592,-0.19533457985008765,0.4780995418310271,-0.1087042533202582,-0.2823103432550844,-0.3005560063777205,-0.02088313501793068,0.5167809061759605,-0.2802996510754724,-0.18394424201657014,-0.16248289913493622,-0.15418471670067987,0.49157335197822094,-0.1833099181855299,0.5047435351537479,-0.07091777510877029,-0.16569684297952736,-0.26448881700385846,-0.030429015562635896,-0.14088955527630562,0.3355326096283207,-0.21152906763916327,0.45624375735381,-0.15967587545778505,-0.16098885240691374,-0.07252056807824932,0.3699606589230686,-0.12516693252